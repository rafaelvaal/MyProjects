# %%
# !jt -t chesterish -tfs 14 -fs 16 -cursw 2 -cursc r -cellw 90% -T -mathfs 110 -lineh 150
plot_theme = 'chesterish'

# Importación de Librerías
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import special as sp
from matplotlib import rc, rcParams
from jupyterthemes import jtplot
from cycler import cycler
dash_espacio = [5,5]

if plot_theme == 'grade3':
    principal_color='black'
else:
    principal_color='white'
    
def grafica_params(fscale=2.6, linea=3):
    jtplot.style(theme=plot_theme, context = 'talk', ticks = True, grid = False, fscale = fscale)
    mpl.rcParams['axes.prop_cycle'] =  cycler(color =[principal_color, 'deepskyblue'])
    plt.rcParams['text.usetex'] = True
    plt.rc('text', usetex=True)
    font = {'family': 'serif', 'weight': 'bold'}
    plt.rc('font', **font)
    plt.rc('lines', lw=linea)
    dash_espacio = [5,5]
    
grafica_params()

# %%
df = pd.read_csv('office_supplies.csv')
df['Order Date'] = pd.to_datetime(df['Order Date'])
df = df.sort_values(by='Order Date')
df.index = df['Order Date']
df['Year'] = df['Order Date'].dt.year
df['Profit vs Quantity'] = df['Profit']/df['Quantity']
# dmin = df['Profit vs Quantity'].min()
# dmax = df['Profit vs Quantity'].max()
# df['Profit vs Quantity'] = (df['Profit vs Quantity'] - dmin)/(dmax - dmin)
df.head()
# Out:
#                   Order ID Order Date       Ship Mode   Region  \
# Order Date
# 2014-01-03  CA-2014-103800 2014-01-03  Standard Class  Central
# 2014-01-04  CA-2014-112326 2014-01-04  Standard Class  Central
# 2014-01-04  CA-2014-112326 2014-01-04  Standard Class  Central
# 2014-01-04  CA-2014-112326 2014-01-04  Standard Class  Central
# 2014-01-05  CA-2014-141817 2014-01-05  Standard Class     East
#
#                  Product ID         Category Sub-Category  \
# Order Date
# 2014-01-03  OFF-PA-10000174  Office Supplies        Paper
# 2014-01-04  OFF-BI-10004094  Office Supplies      Binders
# 2014-01-04  OFF-ST-10002743  Office Supplies      Storage
# 2014-01-04  OFF-LA-10003223  Office Supplies       Labels
# 2014-01-05  OFF-AR-10003478  Office Supplies          Art
#
#                                                  Product Name    Sales  \
# Order Date
# 2014-01-03  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448
# ...

# %%
print('df Shape', df.shape)
print('Not null Profit Df shape', df[pd.notnull(df['Profit'])].shape)
# Out:
# df Shape (9993, 14)
# Not null Profit Df shape (8000, 14)

# %%
plt.figure(figsize=(18,10))
df1 = pd.DataFrame(df.groupby(['Region','Category'])['Quantity', 'Sales','Profit'].sum()).reset_index()                    
df1.head()
plt.figure(figsize=(15,13))
g = sns.barplot(x='Region',y='Quantity',hue='Category', data = df1)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('fig1.pdf', format='PDF')
# Out:
# <ipython-input-5-c485ba5c15d8>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = pd.DataFrame(df.groupby(['Region','Category'])['Quantity', 'Sales','Profit'].sum()).reset_index()

# %%
plt.figure(figsize=(20,13))
g = sns.barplot(x='Region',y='Profit',hue='Category', data = df1)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('fig2.pdf', format='PDF')

# %%
df1 = pd.DataFrame(df.groupby(['Region','Sub-Category'])['Quantity', 'Sales','Profit','Profit vs Quantity'].sum()).reset_index()                    
df1.head()
plt.figure(figsize=(20,13))
g = sns.barplot(x='Region',y='Quantity',hue='Sub-Category', data = df1)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('fig3')
# Out:
# <ipython-input-7-6b1051bf46f8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = pd.DataFrame(df.groupby(['Region','Sub-Category'])['Quantity', 'Sales','Profit','Profit vs Quantity'].sum()).reset_index()

# %%
plt.figure(figsize=(20,13))
g = sns.barplot(x='Region',y='Profit',hue='Sub-Category', data = df1)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('fig4')

# %%
plt.figure(figsize=(20,13))
g = sns.barplot(x='Region',y='Profit vs Quantity', hue='Sub-Category', data = df1)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('fig5')

# %%
sub = pd.DataFrame(df[df['Profit']<-500].groupby(['Region','Sub-Category'])['Profit'].sum())
sub['Profit']
# sub[sub['Profit']<-2000]
# Out:
# Region   Sub-Category
# Central  Appliances      -1947.2944
#          Binders        -10934.1980
#          Machines        -1869.9890
#          Supplies         -786.0144
#          Tables          -1092.2030
# East     Binders          -760.9800
#          Bookcases       -1665.0522
#          Chairs           -630.8820
#          Machines       -12329.3947
#          Supplies        -1049.3406
#          Tables          -1907.7700
# South    Binders         -4641.3071
#          Machines        -7168.0590
#          Tables          -1656.0670
# West     Bookcases        -786.7440
#          Machines        -4338.2600
#          Tables           -814.4832
# Name: Profit, dtype: float64

# %%
df_peryear = pd.DataFrame(df.groupby(['Year','Region','Sub-Category'])['Quantity', 'Sales','Profit'].sum()).reset_index()
g = sns.catplot(x='Region',y='Quantity',hue='Sub-Category', col='Year',data = df_peryear,
                kind='bar', height=8,aspect=1);
# Out:
# <ipython-input-11-b5d9c885d62f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_peryear = pd.DataFrame(df.groupby(['Year','Region','Sub-Category'])['Quantity', 'Sales','Profit'].sum()).reset_index()

# %%
g = sns.catplot(x='Region',y='Profit',hue='Sub-Category', col='Year',data = df_peryear,
                kind='bar', height=8,aspect=1);

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

df2 = df.groupby(['Region','Sub-Category']).resample('3M').sum().reset_index()
df2 = df2[(df2['Sub-Category'] == 'Copiers')|
          (df2['Sub-Category'] == 'Supplies')|
          (df2['Sub-Category'] == 'Machines')|
          (df2['Sub-Category'] == 'Bookcases')|
          (df2['Sub-Category'] == 'Tables')|
          (df2['Sub-Category'] == 'Appliances')
         ]

# %%
plt.figure(figsize=(20,15), dpi=150)
g = sns.FacetGrid(df2, row='Region', hue='Sub-Category', aspect=5, height = 4)
g = g.map(sns.lineplot, 'Order Date', 'Quantity').add_legend(loc='center left', bbox_to_anchor=(1, 0.5), borderaxespad=0)
plt.tight_layout()
plt.savefig('ts-Quantity')

# %%
fig = plt.gcf()
g = sns.FacetGrid(df2, row='Region', hue='Sub-Category', aspect=5, height = 4)
g = g.map(sns.lineplot, 'Order Date', 'Profit').add_legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylim(-1500,1500)
plt.tight_layout()
plt.savefig('ts-Profit')

# %%
fig = plt.gcf()
g = sns.FacetGrid(df2, row='Region', hue='Sub-Category', aspect=5, height = 4)
g = g.map(sns.lineplot, 'Order Date', 'Discount').add_legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('ts-Discount')

# %% [markdown]
# Hi everyone. Mi name is Rafael and i am presenting to you this cse study about the office supplies that we are sending in four diferent regions: East, West, South and Central. It's important to mention, before i continue that, at the moment, all four warehouses stock the same products. And it's of interest for you to see if this is leading to large amounts of unsold products in some locations. So, there are some questions i want to answer for the end of the talk which are: Are there products that do not sell in some locations? and Are there any pattern over time in each region?. So, let's see.
#
# First, let's take a look to popularity over the years 2014 to 2018 through the quantities sold of products grouped by Sub Categories shown in the legend located on the right side. We can see at first sight, that in all regions Copiers, Machines and Supplies tend to be  products with low amounts of sales.  And also, but to a lesser extent Bookcases, Envelopes, Fasteners and Tables present the same behaviour. For some products, as you will see, this is not necesary a disadvantage for the us.
#
#  In the next graph, you can see the profits generated by every sub category, again throught 2014 to 2018. Positive quantities means profits while negative values means losses.  Can be notted that Copiers is one of the most important source of profits despite their low level of sales. On the other hand, we can see that there are some products that tends to produce losses in every region. Tables is the most important source of this losses especially en the east region. But also Machines, bookcases and supplies produces this. Appliances also produce losses but just for the central region. So let's see the patterns formed over time, classified by region and separated by trimester to see what produces thes behaviors.
#
#  We can see that bookcases and tables profits keep below cero, on the losses side, in each region. On the discounts graph im presentig to you now, it can be noted a relation between high discounts, greater than 100%, that produce this losses. On the other hand copiers hasn't present high levels of discounts, so this explain the profits of ciopiers without losses despite low their low popularity.
#
# Lets see now, the same graph but for the quantities sold, to note that appliances had significantly increased sales over time and let's note that this is because of discounts that we saw on the past graph.  This not necesarily produce losses in East, South and West regions, but in Central region, high discounts produced losses over the complete range of time.
#
# So, let me make to you some recomendations like increasing discounts for copiers to increase thier popularity. If this discounts are not to high, this would not produce losses, but they shouldn be of more than 100%. On the other hand, another important recomendation is to reduce discounts, also for less than 100% for Tables, appliances and bookcases to avoid the loss behaviour that had been present on this products.
#
# It is all from me, Thank you for listening. Have a nice day.
